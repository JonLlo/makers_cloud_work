# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql+psycopg2://localhost:5432/window_functions
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# SELECT
#     region,
#     name,
#     amount,
#     RANK() OVER (ORDER BY amount DESC) AS sales_rank
# FROM salespeople ORDER BY region, sales_rank;
# Out:
#  * postgresql+psycopg2://localhost:5432/window_functions
# 10 rows affected.
# [('East', 'Alice', 500, 2),
#  ('East', 'Eve', 450, 3),
#  ('East', 'Jack', 420, 4),
#  ('North', 'Grace', 525, 1),
#  ('North', 'Bob', 400, 5),
#  ('South', 'Dan', 300, 9),
#  ('South', 'Henry', 275, 10),
#  ('West', 'Carla', 400, 5),
#  ('West', 'Iris', 380, 7),
#  ('West', 'Frank', 350, 8)]

# %%
# %%sql
# SELECT *, RANK() OVER (ORDER BY amount DESC) FROM transactions;
# Out:
#  * postgresql+psycopg2://localhost:5432/window_functions
# 50 rows affected.
# [(23, 'CUST2', 493, datetime.date(2025, 2, 1), 1),
#  (35, 'CUST2', 485, datetime.date(2025, 2, 19), 2),
#  (48, 'CUST1', 483, datetime.date(2025, 2, 27), 3),
#  (27, 'CUST1', 453, datetime.date(2025, 1, 26), 4),
#  (25, 'CUST1', 444, datetime.date(2025, 2, 6), 5),
#  (4, 'CUST4', 424, datetime.date(2025, 2, 13), 6),
#  (6, 'CUST3', 423, datetime.date(2025, 2, 26), 7),
#  (21, 'CUST1', 416, datetime.date(2025, 2, 22), 8),
#  (31, 'CUST2', 411, datetime.date(2025, 1, 16), 9),
#  (39, 'CUST1', 403, datetime.date(2025, 3, 2), 10),
#  (34, 'CUST2', 368, datetime.date(2025, 2, 17), 11),
#  (46, 'CUST3', 367, datetime.date(2025, 2, 11), 12),
#  (10, 'CUST1', 358, datetime.date(2025, 2, 11), 13),
#  (9, 'CUST2', 346, datetime.date(2025, 2, 23), 14),
#  (14, 'CUST1', 345, datetime.date(2025, 1, 2), 15),
#  (40, 'CUST3', 310, datetime.date(2025, 1, 22), 16),
#  (19, 'CUST3', 310, datetime.date(2025, 2, 27), 16),
#  (5, 'CUST4', 263, datetime.date(2025, 2, 18), 18),
#  (8, 'CUST3', 262, datetime.date(2025, 2, 13), 19),
#  (37, 'CUST4', 261, datetime.date(2025, 2, 9), 20),
#  (33, 'CUST4', 236, datetime.date(2025, 1, 14), 21),
#  (30, 'CUST1', 225, datetime.date(2025, 1, 31), 22),
#  (15, 'CUST4', 187, datetime.date(2025, 1, 27), 23),
#  (16, 'CUST5', 116, datetime.date(2025, 2, 16), 24),
#  (44, 'CUST2', 93, datetime.date(2025, 2, 1), 25),
#  (24, 'CUST1', 68, datetime.date(2025, 1, 9), 26),
#  (32, 'CUST3', 65, datetime.date(2025, 1, 30), 27),
#  (13, 'CUST2', 63, datetime.date(2025, 2, 2), 28),
#  (3, 'CUST3', 49, datetime.date(2025, 1, 2), 29),
#  (29, 'CUST1', 48, datetime.date(2025, 2, 27), 30),
#  (45, 'CUST4', 46, datetime.date(2025, 1, 18), 31),
#  (17, 'CUST5', 42, datetime.date(2025, 2, 12), 32),
#  (43, 'CUST5', 29, datetime.date(2025, 1, 23), 33),
#  (18, 'CUST5', -1, datetime.date(2025, 2, 2), 34),
#  (36, 'CUST4', -11, datetime.date(2025, 2, 26), 35),
#  (38, 'CUST4', -24, datetime.date(2025, 2, 5), 36),
#  (42, 'CUST4', -25, datetime.date(2025, 2, 23), 37),
#  (26, 'CUST1', -55, datetime.date(2025, 1, 20), 38),
#  (2, 'CUST4', -55, datetime.date(2025, 1, 7), 38),
#  (12, 'CUST4', -59, datetime.date(2025, 1, 11), 40),
#  (47, 'CUST1', -88, datetime.date(2025, 3, 2), 41),
#  (28, 'CUST2', -105, datetime.date(2025, 1, 14), 42),
#  (1, 'CUST5', -106, datetime.date(2025, 2, 3), 43),
#  (41, 'CUST2', -112, datetime.date(2025, 2, 23), 44),
#  (22, 'CUST5', -130, datetime.date(2025, 2, 7), 45),
#  (7, 'CUST1', -131, datetime.date(2025, 1, 15), 46),
#  (11, 'CUST3', -142, datetime.date(2025, 1, 12), 47),
#  (49, 'CUST3', -179, datetime.date(2025, 1, 3), 48),
#  (50, 'CUST5', -180, datetime.date(2025, 3, 2), 49),
#  (20, 'CUST5', -189, datetime.date(2025, 1, 21), 50)]
